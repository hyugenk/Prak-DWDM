# %% [markdown]
# #Quiz

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('CustomerSegmentation.csv')
print(data)
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
# Soal 1
# kita bisa menggunakan info() untuk mengetahui jumlah baris dan kolom
# untuk jumlah baris bisa kita ketahui dari range index, untuk kolom dari data colums (obviously)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               8068 non-null   int64
#  1   Gender           8068 non-null   object
#  2   Ever_Married     7928 non-null   object
#  3   Age              8068 non-null   int64
#  4   Graduated        7990 non-null   object
#  5   Profession       7944 non-null   object
#  6   Work_Experience  7239 non-null   float64
#  7   Spending_Score   8068 non-null   object
#  8   Family_Size      7733 non-null   float64
#  9   Var_1            7992 non-null   object
#  10  Segmentation     8068 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 693.5+ KB

# %%
# Soal 2
data.describe()

# rata-rata usia customer = 43
# usia paling muda = 18
# usia paling tua = 89
# Out:
#                   ID          Age  Work_Experience  Family_Size
# count    8068.000000  8068.000000      7239.000000  7733.000000
# mean   463479.214551    43.466906         2.641663     2.850123
# std      2595.381232    16.711696         3.406763     1.531413
# min    458982.000000    18.000000         0.000000     1.000000
# 25%    461240.750000    30.000000         0.000000     2.000000
# 50%    463472.500000    40.000000         1.000000     3.000000
# 75%    465744.250000    53.000000         4.000000     4.000000
# max    467974.000000    89.000000        14.000000     9.000000

# %%
data['Gender'] = data['Gender'].map({'Male' : 1, 'Female' : 0})

# %%
# Soal 3

# bisa, caranya pakai

gender = data.Gender

male = gender == 1
female = gender == 0

print(male.sum())
print(female.sum())
# Out:
# 4417
# 3651

# %%
# Soal 4

data.head()
segmentation = data.Segmentation.drop_duplicates()
print(segmentation)
# Out:
# 0    D
# 1    A
# 2    B
# 5    C
# Name: Segmentation, dtype: object

# %%
# Soal 5

ceknull = data.columns
for item in ceknull:
    print(item + ' -n ' + str(data[item].isnull().sum()))
# Out:
# ID -n 0
# Gender -n 0
# Ever_Married -n 140
# Age -n 0
# Graduated -n 78
# Profession -n 124
# Work_Experience -n 829
# Spending_Score -n 0
# Family_Size -n 335
# Var_1 -n 76
# Segmentation -n 0

# %%
# Soal 6

sns.catplot(x='Gender', col='Gender', data=data, kind='count')

# %%
# Soal 7

data.head(10)
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809       1           No   22        No     Healthcare              1.0
# 1  462643       0          Yes   38       Yes       Engineer              NaN
# 2  466315       0          Yes   67       Yes       Engineer              1.0
# 3  461735       1          Yes   67       Yes         Lawyer              0.0
# 4  462669       0          Yes   40       Yes  Entertainment              NaN
# 5  461319       1          Yes   56        No         Artist              0.0
# 6  460156       1           No   32       Yes     Healthcare              1.0
# 7  464347       0           No   33       Yes     Healthcare              1.0
# 8  465015       0          Yes   61       Yes       Engineer              0.0
# 9  465176       0          Yes   55       Yes         Artist              1.0
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# ...

# %%
# Soal 8

# saya akan mendrop data yang tidak perlu seperti (id)
data.drop(columns=["ID"], inplace=True)

# %%
# lalu saya akan sebisa mungkin mengubah data menjadi angka (gender, ever married, graduated)
data['Ever_Married'] = data['Ever_Married'].map({'Yes' : 1, 'No' : 0})
data['Graduated'] = data['Graduated'].map({'Yes' : 1, 'No' : 0})

# %%
data.head(10)
# Out:
#        ID  Gender  Ever_Married  Age  Graduated     Profession  \
# 0  462809       1           0.0   22        0.0     Healthcare
# 1  462643       0           1.0   38        1.0       Engineer
# 2  466315       0           1.0   67        1.0       Engineer
# 3  461735       1           1.0   67        1.0         Lawyer
# 4  462669       0           1.0   40        1.0  Entertainment
# 5  461319       1           1.0   56        0.0         Artist
# 6  460156       1           0.0   32        1.0     Healthcare
# 7  464347       0           0.0   33        1.0     Healthcare
# 8  465015       0           1.0   61        1.0       Engineer
# 9  465176       0           1.0   55        1.0         Artist
#
#    Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0              1.0            Low          4.0  Cat_4            D
# 1              NaN        Average          3.0  Cat_4            A
# 2              1.0            Low          1.0  Cat_6            B
# ...

# %%
# terus saya akan menggunakan heatmap untuk memilih 5 fitur terbaik

sns.heatmap(data.corr(), annot=True, cmap="Greens")
# Out:
# <ipython-input-44-039aee36171c>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, cmap="Greens")
# <Axes: >

# %%
# Soal 9
